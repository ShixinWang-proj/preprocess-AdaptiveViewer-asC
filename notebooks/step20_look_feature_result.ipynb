# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %%
dp = r"D:\Workspace\1_Projects\PPG_24H_Pipeline\data"

# %%
fn = "pipeline_events.csv"
fp = os.path.join(dp, fn)

# %%
df = pd.read_csv(fp)

# %%
df_f = df[(df.Area_Down < 4e6)&(df.Area_Up < 1e7)]
df_f
# Out:
#                   timestamp  HR_Raw  RRI_ms  Area_Up  Area_Down  Peak_Index  \
# 0       26-05-2026 11:15:42    75.0  800.00     2000       3000          -1
# 1       26-05-2026 11:15:42    75.0  800.00     2000       3000          -1
# 2       26-05-2026 11:15:43    75.0  800.00     2000       3000          -1
# 3       26-05-2026 11:15:44    75.0  800.00     2000       3000          -1
# 4       26-05-2026 11:15:45    75.0  800.00     2000       3000          -1
# ...                     ...     ...     ...      ...        ...         ...
# 106603  27-05-2026 13:31:32    93.8  640.00        0          0          -1
# 106604  27-05-2026 13:31:33    95.2  630.00        0          0          -1
# 106605  27-05-2026 13:31:33    82.0  731.43        0          0          -1
# 106606  27-05-2026 13:31:34    83.2  721.43        0          0          -1
# 106607  27-05-2026 13:31:35    82.0  731.43        0          0          -1
#
# ...

# %%
df_f.Area_Down.hist(bins=200)
# Out:
# <Axes: >

# %%
df.Area_Up.hist(bins=200)
# Out:
# <Axes: >

# %%
df[df.Area_Down == 0]
# Out:
#                   timestamp  HR_Raw   RRI_ms  Area_Up  Area_Down  Peak_Index  \
# 2173    26-05-2026 11:40:40    58.6  1024.00        0          0          -1
# 2174    26-05-2026 11:40:41   175.8   341.33        0          0          -1
# 2177    26-05-2026 11:40:42    93.8   640.00        0          0          -1
# 2179    26-05-2026 11:40:44    82.0   731.43        0          0          -1
# 2181    26-05-2026 11:40:45    82.0   731.43        0          0          -1
# ...                     ...     ...      ...      ...        ...         ...
# 106603  27-05-2026 13:31:32    93.8   640.00        0          0          -1
# 106604  27-05-2026 13:31:33    95.2   630.00        0          0          -1
# 106605  27-05-2026 13:31:33    82.0   731.43        0          0          -1
# 106606  27-05-2026 13:31:34    83.2   721.43        0          0          -1
# 106607  27-05-2026 13:31:35    82.0   731.43        0          0          -1
#
# ...
